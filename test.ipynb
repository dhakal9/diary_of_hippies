# %%
# Out:
# Running cells with '.venv (3.11.3) (Python 3.11.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/amrit/OneDrive/Desktop/diary_of_hippies/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
